# %% [markdown]
# <a href="https://colab.research.google.com/github/ildacec/Python_Reto100diasconPython/blob/main/2022_numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount ('/content/drive')

from IPython.display import Image
#filename = "img1.png", width = 600, height = 300
Image (filename ='/content/drive/MyDrive/Colab Notebooks/Python/numpy-1-1-.png', width = 300, height = 200)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Biblioteca NumPy
#
# NumPy significa Python numérico ("Numerical Python").
#
#
# ---
#
#
# Es una biblioteca de Python para realizar cálculos numéricos a gran escala.
# Las matrices se utilizan con mucha frecuencia en la Ciencia de datos, donde la velocidad y los recursos son muy importantes, para responder problemas de aprendizaje automático.
#
#
# ---

# %%
#PIP
#Si tu usas  pip, puedes instalar NumPy con el siguiente comando:

pip install numpy

# %%
#Para comenzar a usar Numpy en su script, tienes que importarlo.
import numpy as np

# %%
#PyLadiesPanamá
#Biblioteca NumPy

arr = np.array(['1', '2', '3', '4', '5'])
print(arr)
# Out:
# ['1' '2' '3' '4' '5']
