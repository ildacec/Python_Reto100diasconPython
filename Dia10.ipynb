# %% [markdown]
# <a href="https://colab.research.google.com/github/ildacec/Python_Reto100diasconPython/blob/main/Dia10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount ('/content/drive')

from IPython.display import Image
#filename = "img1.png", width = 600, height = 300
Image (filename ='/content/drive/MyDrive/Colab Notebooks/Python/reto10.jpg', width = 400, height = 300)
# Out:
# Mounted at /content/drive

# %%
##100diasdepython

#Panamá
#Reto Día 10


num1 = num2 = num3 = 33

print(num1, num2, num3)
# Out:
# 33 33 33
