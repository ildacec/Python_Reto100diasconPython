# %% [markdown]
# <a href="https://colab.research.google.com/github/ildacec/Python_Reto100diasconPython/blob/main/2022_DiaDelPadre.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount ('/content/drive')

from IPython.display import Image
#filename = "img1.png", width = 600, height = 300
Image (filename ='/content/drive/MyDrive/Colab Notebooks/Python/2022-diadelpadre.JPG', width = 600, height = 300)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
## @Python Panama y @Pyladies Panamá 

fecha = '19/Jun/2022'
celebracion = "Día del Padre"
felicitaciones= 'A todos los papas en su día y a los papas familiares de cada uno de los miembros de Python Panamá y Pyladies Panamá'

mensaje = 'Hoy: ' + fecha + ', en el ' + celebracion + ', les deseamos Felicidades!!!  ' + felicitaciones
print (mensaje)
# Out:
# Hoy: 19/Jun/2022, en el Día del Padre, les deseamos Felicidades!!!  A todos los papas en su día y a los papas familiares de cada uno de los miembros de Python Panamá y Pyladies Panamá
