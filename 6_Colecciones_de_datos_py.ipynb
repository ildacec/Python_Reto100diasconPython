# %% [markdown]
# <a href="https://colab.research.google.com/github/ildacec/Python_Reto100diasconPython/blob/main/6_Colecciones_de_datos_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Desde Cero 🐍
#
# Pyladies Panamá 🌻
#
# 2022
#
#
# ---
#
# Day 4 - PythonDesdeCero Challenge
# * Sábado 10/Septiembre/2022
#
#
# ---
# Autor: Asabeneh

# %% [markdown]
# # Colecciones de Datos
#
# Un poco más a detalle sobre las collecciones de datos
#
# ![image.png](data:image/png;base64,...)

# %%
#Listas 
list1= [1,4,"Data",6,"college"]
list2=[]  # creates an empty list
list3=list((1,2,3))

print(list1)
print(list2)
print(list3)

# %%
#tuplas

tuple1=(1,2,"college",9,'r','d', 7,3)
tuple2=() # creates an empty tuple
tuple3=tuple((1,8,5,9, "hello"))

print(tuple1)
print(tuple2)
print(tuple3)
# Out:
# (1, 2, 'college', 9, 'r', 'd', 7, 3)
# ()
# (1, 8, 5, 9, 'hello')

# %%
print(tuple())

print(tuple((7, 2, 3)))


print(tuple("Python"))


print(tuple([1, 2, 3]))
# Out:
# ()
# (7, 2, 3)
# ('P', 'y', 't', 'h', 'o', 'n')
# (1, 2, 3)

# %%
#Set  / Conjuntos 
set1={1,2,3,4,5,"hello","tup",10,33, "camino"}
set2={(1,8,"python",7)}
set3={(10,8,"python",7)}

print(set1)
print(set2)
print(set3)
# Out:
# {1, 2, 3, 4, 5, 33, 'hello', 'tup', 10, 'camino'}
# {(1, 8, 'python', 7)}
# {(10, 8, 'python', 7)}

# %%
#Diccionarios 
dict1={"key1":"value1","key2":"value2"}
dict2={}   # empty dictionary
dict3=dict({1:"apple",2:"cherry",3:"strawberry"})

print(dict1)
print(dict2)
print(dict3)
# Out:
# {'key1': 'value1', 'key2': 'value2'}
# {}
# {1: 'apple', 2: 'cherry', 3: 'strawberry'}

# %% [markdown]
# # Inserción de Datos
# https://www-golinuxcloud-com.translate.goog/python-list-vs-set-vs-tuple-vs-dictionary/?_x_tr_sl=en&_x_tr_tl=es&_x_tr_hl=es&_x_tr_pto=wapp

# %%
# Program to demonstrate list vs set vs tuple vs dictionary
# Initializing data structures
l=[1,2] # List
t=(1,2) # Tuple
s={1,2} # Set
d={"Name":"Raj","Age":25} # Dictionary

# Insertion in List
l.append(10)
l.append(20)
l.append(30)
print("List is",l)

# Insertion in Tuple
print("You cannot insert new elements to the tuple. Tuple is",t)

# Insertion in Set
s.add(10)
s.add(20)
print("Set is",s)

# Insertion in Dictionary
d.update({"Location":"Mumbai"})
d.update({"Experience":7.5})
print("Dictionary is",d)

d.update({"Name":"Ilda"})
print("Dictionary is",d)
# Out:
# List is [1, 2, 10, 20, 30]
# You cannot insert new elements to the tuple. Tuple is (1, 2)
# Set is {1, 2, 10, 20}
# Dictionary is {'Name': 'Raj', 'Age': 25, 'Location': 'Mumbai', 'Experience': 7.5}
# Dictionary is {'Name': 'Ilda', 'Age': 25, 'Location': 'Mumbai', 'Experience': 7.5}

# %% [markdown]
# # Borrado de Datos en Colecciones

# %%
# Program to demonstrate list vs set vs tuple vs dictionary
 # Initializing data structures
l=[1,2,3,4,5] # List
t=(1,2,3,4,5) # Tuple
s={1,2,3,4,5} # Set
d={"Name":"Raj","Age":25} # Dictionary

# Deletion in List
print("Value deleted from the list is",l.pop(2))
print("List is",l)

# Deletion in Tuple
print("You cannot delete an element from the tuple")
print("Tuple is",t)

# Deletion in Set
print("Value deleted from the Set is",s.pop())
print("Set is ",s)
# Deletion in Set
print("Value deleted from the Set is",s.pop())
print("Set is ",s)

# Deletion in Dictionary
print("Value deleted from the Dictionary is",d.pop("Age"))
print("Dictionary is",d)
# Out:
# Value deleted from the list is 3
# List is [1, 2, 4, 5]
# You cannot delete an element from the tuple
# Tuple is (1, 2, 3, 4, 5)
# Value deleted from the Set is 1
# Set is  {2, 3, 4, 5}
# Value deleted from the Set is 2
# Set is  {3, 4, 5}
# Value deleted from the Dictionary is 25
# Dictionary is {'Name': 'Raj'}

# %%
s={1,2,3,4,5} # Set
print(s)

# Deletion in Set
print("Value deleted from the Set is",s.pop())
print("Set is ",s)
# Deletion in Set
print("Value deleted from the Set is",s.pop())
print("Set is ",s)

# Deletion in Set
print("Value deleted from the Set is",s.pop())
print("Set is ",s)
# Out:
# {1, 2, 3, 4, 5}
# Value deleted from the Set is 1
# Set is  {2, 3, 4, 5}
# Value deleted from the Set is 2
# Set is  {3, 4, 5}
# Value deleted from the Set is 3
# Set is  {4, 5}

# %% [markdown]
# # Orden de datos en colecciones

# %%
# Program to demonstrate list vs set vs tuple vs dictionary
 # Initializing data structures
l=[110,2,43,54,599] # List
t=(110,2,43,54,599) # Tuple
s={110,12,43,54,599} # Set
d={"Name":"Raj","Age":25, "Location":"Mumbai"} # Dictionary

# Sorting in List
print("Unsorted list is ",l)
l.sort()
print("Sorted list is ",l)


# Sorting a Tuple
print("\nUnsorted tuple is ",t)
print("Sorted tuple is ",sorted(t))
print("Original tuple is ",t)

# Sorting a Set
print("\nUnsorted set is ",s)
print("Sorted set is ",sorted(s))
print("Original set is ",s)

# Sorting a Dictionary
print("\nUnsorted dictionary is ",d)
print("Sorted dictionary is ",sorted(d))
print("Original dictionary is ",d)
# Out:
# Unsorted list is  [110, 2, 43, 54, 599]
# Sorted list is  [2, 43, 54, 110, 599]
#
# Unsorted tuple is  (110, 2, 43, 54, 599)
# Sorted tuple is  [2, 43, 54, 110, 599]
# Original tuple is  (110, 2, 43, 54, 599)
#
# Unsorted set is  {43, 12, 110, 54, 599}
# Sorted set is  [12, 43, 54, 110, 599]
# Original set is  {43, 12, 110, 54, 599}
#
# Unsorted dictionary is  {'Name': 'Raj', 'Age': 25, 'Location': 'Mumbai'}
# Sorted dictionary is  ['Age', 'Location', 'Name']
# Original dictionary is  {'Name': 'Raj', 'Age': 25, 'Location': 'Mumbai'}
