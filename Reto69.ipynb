# %% [markdown]
# <a href="https://colab.research.google.com/github/ildacec/Python_Reto100diasconPython/blob/main/Reto69.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount ('/content/drive')

from IPython.display import Image
#filename = "img1.png", width = 600, height = 300
Image (filename ='/content/drive/MyDrive/Colab Notebooks/Python/reto69.jpg', width = 400, height = 300)
# Out:
# Mounted at /content/drive

# %%
#100diasdePython
#PyladiesPanama
#"Utiliza Regex para extraer todas las 'a' seguidas de una omas 'b' de la siguiente cadena"

import re

cadena_ilda = "abholaaaaabaaabbpythonistaaaaaabbbbb"
regex_cadena = re.findall(r"a+b",cadena_ilda)
print(regex_cadena)
# Out:
# ['ab', 'aaaaab', 'aaab', 'aaaaaab']
