# %% [markdown]
# <a href="https://colab.research.google.com/github/ildacec/Python_Reto100diasconPython/blob/main/Reto71.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount ('/content/drive')

from IPython.display import Image
#filename = "img1.png", width = 600, height = 300
Image (filename ='/content/drive/MyDrive/Colab Notebooks/Python/reto71.jpg', width = 400, height = 400)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#100díaconPython
#PyladiesPanama

#Utiliza itertools 
import itertools
import operator

lista_ilda = [0,1,1,2,3,5,8]

result = list(itertools.accumulate(lista_ilda, operator.add))

print(result)
# Out:
# [0, 1, 2, 4, 7, 12, 20]
