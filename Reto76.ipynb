# %% [markdown]
# <a href="https://colab.research.google.com/github/ildacec/Python_Reto100diasconPython/blob/main/Reto76.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount ('/content/drive')

from IPython.display import Image
#filename = "img1.png", width = 600, height = 300
Image (filename ='/content/drive/MyDrive/Colab Notebooks/Python/reto76.jpg', width = 400, height = 400)
# Out:
# Mounted at /content/drive

# %%
#100díasconPython
#Pyladies Panama

import itertools

list_ilda = [(2, 4, 6), (7, 8, 5, 6), (5, 10)]


maximo = [max(itertools.chain(x)) for x in list_ilda]
print(maximo)
# Out:
# [6, 8, 10]
